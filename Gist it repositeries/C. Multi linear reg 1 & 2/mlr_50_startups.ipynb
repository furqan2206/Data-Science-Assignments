# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf

# %%
df=pd.read_csv('50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
#checcking for missing values
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
#checking for duplicate records
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
#renaming the columns
df1=df.rename({'R&D Spend':'rds','Administration':'admn','Marketing Spend':'mkts'}, axis=1)

# %%
df1.head()
# Out:
#          rds       admn       mkts       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# # Correlation analysis

# %%
df1.corr()
# Out:
#              rds      admn      mkts    Profit
# rds     1.000000  0.241955  0.724248  0.972900
# admn    0.241955  1.000000 -0.032154  0.200717
# mkts    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %% [markdown]
# # visualization b/w variables

# %%
#scatter plots and histograms

# %%
sns.set_style(style='darkgrid')
sns.pairplot(df1)

# %% [markdown]
# # Model building

# %%
model= smf.ols('Profit~rds+admn+mkts',data=df1).fit()

# %% [markdown]
# # Model testing

# %%
#co-efficient of model
model.params
# Out:
# Intercept    50122.192990
# rds              0.805715
# admn            -0.026816
# mkts             0.027228
# dtype: float64

# %%
#summary of the model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           4.53e-30
# Time:                        17:40:22   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
# Since the p value for Administration and Marketing Spend is > 0.05 build simple linear regression and multi linear regression models  to see insignificant variables

# %%
slr_admn=smf.ols('Profit~admn',data=df1).fit()

# %%
slr_admn.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):              0.162
# Time:                        17:40:22   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %%
#build the linear model to check the column marketing
slr_mar = smf.ols('Profit~mkts',data=df1).fit()

# %%
slr_mar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           4.38e-10
# Time:                        17:40:22   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...

# %%
#Build the multi linear regression modelof administration and marketing together to check for collinearity problem
slr_admn= smf.ols('Profit~admn',data=df1).fit()

# %%
slr_admn.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):              0.162
# Time:                        17:40:22   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %%
#Build a simple linear model to check the column marketing
slr_mar=smf.ols('Profit~mkts',data=df1).fit()

# %%
slr_mar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           4.38e-10
# Time:                        17:40:22   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...

# %%
# Build the Multi Linear regression model of Adminstration and Marketing together to check for collinearity problem
slr_am = smf.ols('Profit~admn+mkts',data=df1).fit()

# %%
slr_am.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     36.71
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           2.50e-10
# Time:                        17:40:22   Log-Likelihood:                -577.13
# No. Observations:                  50   AIC:                             1160.
# Df Residuals:                      47   BIC:                             1166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.022e+04   1.77e+04      1.143      0.259   -1.54e+04    5.58e+04
# ...

# %% [markdown]
# # Model validation techniques

# %%
#Two techniques
#1)Collinearity check-VIF
#2)Residual analysis
# Calculating variance inflation factor(VIF)= 1/1-r2

# %%
rsq_rds = smf.ols('rds~admn+mkts',data=df1).fit().rsquared  
vif_rds = 1/(1-rsq_rds) 
vif_rds
# Out:
# 2.468903069994701

# %%
rsq_admn = smf.ols('admn~rds+mkts',data=df1).fit().rsquared  
vif_admn= 1/(1-rsq_admn) 
vif_admn
# Out:
# 1.175091007055045

# %%
rsq_mkts = smf.ols('mkts~rds+admn',data=df1).fit().rsquared  
vif_mkts = 1/(1-rsq_mkts) 
vif_mkts
# Out:
# 2.3267732905308773

# %%
df1.head()
# Out:
#          rds       admn       mkts       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
# Storing vif values in a data frame
d1 = {'Variables':['rds','admn','mkts'],'VIF':[vif_rds,vif_admn,vif_mkts]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0       rds  2.468903
# 1      admn  1.175091
# 2      mkts  2.326773

# %% [markdown]
# Since No value of VIF is greater than 20 , we can say that there is no collinearity problem. So we shall consider all columns for building the model

# %% [markdown]
# # Residual analysis

# %% [markdown]
# # Test for normality of residuals(Q-Q plot)

# %%
import statsmodels.api as sm
sns.set_style(style='darkgrid')
qqplot=sm.qqplot(model.resid,line='q') 
# line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-10000))
# Out:
# [array([14, 15, 48, 49], dtype=int64)]

# %% [markdown]
# Residual Plot for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()  #User Defined Function Z = (x-mu)/sigma

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# # Residual vs regressor

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "rds", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "admn", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "mkts", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Delition Diagnostics

# %%
#Detecting outliers
#Cook's distance

# %%
  model_influence = model.get_influence()
  (c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
sns.set_style(style='darkgrid')
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df1)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %% [markdown]
# There are no datapoints whose value is greater than 0.5

# %% [markdown]
# # High Influence Plots

# %%
fig,ax=plt.subplots(figsize=(15,10))
fig=influence_plot(model,ax = ax)

# %%
plt.show()

# %%
k = df1.shape[1]     
# k = no.of features/columns & n = no. of datapoints
n = df1.shape[0] 
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.36

# %%
df1[df1.index.isin([49])]
# Out:
#     rds      admn      mkts       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
df1.shape
# Out:
# (50, 5)

# %% [markdown]
# # Improving the model

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
df2=df1.copy()
df2
# Out:
#           rds       admn       mkts       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
df2=df1.drop(df1.index[[49]],axis=0).reset_index(drop=True)
df2
# Out:
#           rds       admn       mkts       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# # Model Deletion Diagoniostics & Final Model

# %%
Final_Model = smf.ols('Profit~rds+admn+mkts',data=df2).fit()

# %%
Final_Model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):           8.85e-32
# Time:                        17:40:28   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.238e+04   5542.657      9.451      0.000    4.12e+04    6.35e+04
# ...

# %% [markdown]
# # Model predictions

# %%
#New data for prediction
df3=pd.DataFrame({'rds':78000,'admn':127864.55,"mkts":249839.44},index=[1])
df3
# Out:
#      rds       admn       mkts
# 1  78000  127864.55  249839.44

# %%
Final_Model.predict(df3)
# Out:
# 1    116922.172202
# dtype: float64

# %%
#Automatic prediction
pred_y= Final_Model.predict(df2)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %%
d2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,Final_Model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.961316
